# %%
#list的運算,需要利用迴圈
import random
chinese = [random.randint(60, 100) for _ in range(50)]
english = [random.randint(60, 100) for _ in range(50)]

result = []
for i in range(50):
    total = chinese[i] + english[i]
    result.append(total)

result
# Out:
# [133,
#  149,
#  156,
#  139,
#  171,
#  161,
#  124,
#  158,
#  157,
#  124,
#  161,
#  169,
#  171,
#  134,
#  166,
#  169,
#  155,
#  150,
#  170,
#  163,
#  132,
#  160,
#  157,
#  155,
#  135,
#  149,
#  140,
#  185,
#  149,
#  177,
#  179,
#  164,
#  140,
#  161,
#  181,
#  158,
#  181,
#  150,
#  146,
#  138,
#  139,
#  158,
#  161,
#  131,
#  143,
#  160,
#  178,
#  148,
#  152,
#  163]

# %%
#使用numpy,陣列運算

import numpy as np
chinese = np.random.randint(60, high=100, size=50)
english = np.random.randint(60, high=100, size=50)
result = chinese + english
result
# Out:
# array([145, 147, 139, 163, 123, 177, 167, 148, 178, 177, 169, 166, 141,
#        158, 168, 161, 164, 144, 134, 165, 177, 147, 127, 176, 160, 156,
#        147, 162, 170, 146, 163, 121, 133, 156, 149, 162, 154, 128, 145,
#        175, 186, 166, 189, 146, 192, 158, 161, 129, 164, 133])

# %%
#50個學生,5個分數
import numpy as np

students = np.random.randint(60,high=100,size=(50, 5)) #2維
print(students)
sum = np.sum(students,axis=1)
average = np.average(students,axis=1)
print(sum)
print("============")
print(average)
# Out:
# [[73 62 85 94 95]
#  [74 93 75 97 79]
#  [89 75 67 70 71]
#  [77 74 68 62 80]
#  [62 86 96 62 72]
#  [77 68 79 96 74]
#  [69 94 68 75 73]
#  [87 69 80 70 98]
#  [76 74 74 64 93]
#  [89 93 77 90 66]
#  [62 84 87 79 95]
#  [86 67 62 82 60]
#  [64 95 99 95 89]
#  [80 61 76 85 99]
#  [68 86 60 75 98]
#  [60 65 69 63 79]
#  [80 75 94 95 78]
#  [93 70 83 62 80]
#  [67 99 80 99 82]
#  [65 80 74 73 76]
#  [66 96 97 87 88]
#  [80 89 93 99 69]
#  [74 72 64 69 89]
#  [96 67 79 86 98]
#  [86 72 70 83 75]
#  [63 96 99 84 87]
#  [72 61 60 70 98]
#  [91 67 80 73 86]
#  [63 82 78 82 96]
#  [84 95 79 67 61]
#  [71 73 81 99 65]
#  [75 73 69 70 65]
#  [82 95 78 67 70]
#  [76 84 69 82 67]
#  [70 99 61 85 77]
#  [80 94 85 92 71]
#  [90 72 83 75 89]
#  [64 92 90 63 84]
#  [72 79 60 64 87]
#  [79 69 78 73 74]
#  [91 81 66 71 83]
#  [95 81 98 96 84]
#  [75 74 67 64 75]
#  [96 72 80 77 93]
#  [96 60 87 66 71]
#  [91 91 66 73 97]
#  [91 67 99 98 90]
#  [78 80 80 84 66]
#  [76 94 88 73 95]
#  [67 75 62 95 60]]
# [409 418 372 361 378 394 379 404 381 415 407 357 442 401 387 336 422 388
#  427 368 434 430 368 426 386 429 361 397 401 386 389 352 392 378 392 422
#  409 393 362 373 392 454 355 418 380 418 445 388 426 359]
# ============
# [81.8 83.6 74.4 72.2 75.6 78.8 75.8 80.8 76.2 83.  81.4 71.4 88.4 80.2
#  77.4 67.2 84.4 77.6 85.4 73.6 86.8 86.  73.6 85.2 77.2 85.8 72.2 79.4
#  80.2 77.2 77.8 70.4 78.4 75.6 78.4 84.4 81.8 78.6 72.4 74.6 78.4 90.8
#  71.  83.6 76.  83.6 89.  77.6 85.2 71.8]

# %%
for i in range(50):
    print(students[i])
# Out:
# [73 62 85 94 95]
# [74 93 75 97 79]
# [89 75 67 70 71]
# [77 74 68 62 80]
# [62 86 96 62 72]
# [77 68 79 96 74]
# [69 94 68 75 73]
# [87 69 80 70 98]
# [76 74 74 64 93]
# [89 93 77 90 66]
# [62 84 87 79 95]
# [86 67 62 82 60]
# [64 95 99 95 89]
# [80 61 76 85 99]
# [68 86 60 75 98]
# [60 65 69 63 79]
# [80 75 94 95 78]
# [93 70 83 62 80]
# [67 99 80 99 82]
# [65 80 74 73 76]
# [66 96 97 87 88]
# [80 89 93 99 69]
# [74 72 64 69 89]
# [96 67 79 86 98]
# [86 72 70 83 75]
# [63 96 99 84 87]
# [72 61 60 70 98]
# [91 67 80 73 86]
# [63 82 78 82 96]
# [84 95 79 67 61]
# [71 73 81 99 65]
# [75 73 69 70 65]
# [82 95 78 67 70]
# [76 84 69 82 67]
# [70 99 61 85 77]
# [80 94 85 92 71]
# [90 72 83 75 89]
# [64 92 90 63 84]
# [72 79 60 64 87]
# [79 69 78 73 74]
# [91 81 66 71 83]
# [95 81 98 96 84]
# [75 74 67 64 75]
# [96 72 80 77 93]
# [96 60 87 66 71]
# [91 91 66 73 97]
# [91 67 99 98 90]
# [78 80 80 84 66]
# [76 94 88 73 95]
# [67 75 62 95 60]

# %%
students.ndim, students.shape, students.size, students.dtype
# Out:
# (2, (50, 5), 250, dtype('int64'))

# %%
#建立ndarray
#將list轉成ndarray
list = [[1, 2, 3], [2, 3, 4]]
np.array(list)
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
#使用numpy random
np.random.randn(3,4)
# Out:
# array([[ 0.00418886, -0.38395969, -0.36617966, -0.67526827],
#        [ 0.3818079 , -0.19719666, -0.47831888, -0.2435273 ],
#        [ 0.80969275, -0.70850097,  0.92104398,  0.76664006]])

# %%
#做用numpy 內建的function
print(np.zeros((2,3)))

np.linspace(-3,3,num=50)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]
# array([-3.        , -2.87755102, -2.75510204, -2.63265306, -2.51020408,
#        -2.3877551 , -2.26530612, -2.14285714, -2.02040816, -1.89795918,
#        -1.7755102 , -1.65306122, -1.53061224, -1.40816327, -1.28571429,
#        -1.16326531, -1.04081633, -0.91836735, -0.79591837, -0.67346939,
#        -0.55102041, -0.42857143, -0.30612245, -0.18367347, -0.06122449,
#         0.06122449,  0.18367347,  0.30612245,  0.42857143,  0.55102041,
#         0.67346939,  0.79591837,  0.91836735,  1.04081633,  1.16326531,
#         1.28571429,  1.40816327,  1.53061224,  1.65306122,  1.7755102 ,
#         1.89795918,  2.02040816,  2.14285714,  2.26530612,  2.3877551 ,
#         2.51020408,  2.63265306,  2.75510204,  2.87755102,  3.        ])

# %%
x = np.linspace(-3,3,num=50)
x
# Out:
# array([-3.        , -2.87755102, -2.75510204, -2.63265306, -2.51020408,
#        -2.3877551 , -2.26530612, -2.14285714, -2.02040816, -1.89795918,
#        -1.7755102 , -1.65306122, -1.53061224, -1.40816327, -1.28571429,
#        -1.16326531, -1.04081633, -0.91836735, -0.79591837, -0.67346939,
#        -0.55102041, -0.42857143, -0.30612245, -0.18367347, -0.06122449,
#         0.06122449,  0.18367347,  0.30612245,  0.42857143,  0.55102041,
#         0.67346939,  0.79591837,  0.91836735,  1.04081633,  1.16326531,
#         1.28571429,  1.40816327,  1.53061224,  1.65306122,  1.7755102 ,
#         1.89795918,  2.02040816,  2.14285714,  2.26530612,  2.3877551 ,
#         2.51020408,  2.63265306,  2.75510204,  2.87755102,  3.        ])

# %%
y1 = 2 * x + 1
y1

y2 = x ** 2
y2
# Out:
# array([9.00000000e+00, 8.28029988e+00, 7.59058726e+00, 6.93086214e+00,
#        6.30112453e+00, 5.70137443e+00, 5.13161183e+00, 4.59183673e+00,
#        4.08204915e+00, 3.60224906e+00, 3.15243648e+00, 2.73261141e+00,
#        2.34277384e+00, 1.98292378e+00, 1.65306122e+00, 1.35318617e+00,
#        1.08329863e+00, 8.43398584e-01, 6.33486047e-01, 4.53561016e-01,
#        3.03623490e-01, 1.83673469e-01, 9.37109538e-02, 3.37359434e-02,
#        3.74843815e-03, 3.74843815e-03, 3.37359434e-02, 9.37109538e-02,
#        1.83673469e-01, 3.03623490e-01, 4.53561016e-01, 6.33486047e-01,
#        8.43398584e-01, 1.08329863e+00, 1.35318617e+00, 1.65306122e+00,
#        1.98292378e+00, 2.34277384e+00, 2.73261141e+00, 3.15243648e+00,
#        3.60224906e+00, 4.08204915e+00, 4.59183673e+00, 5.13161183e+00,
#        5.70137443e+00, 6.30112453e+00, 6.93086214e+00, 7.59058726e+00,
#        8.28029988e+00, 9.00000000e+00])

# %%
import matplotlib.pyplot as plt
figure = plt.figure(figsize=(8,5))
axes = figure.add_subplot(1,1,1)
#畫布列分割為1, 行分割為1, 呈現1圖塊 
axes.plot(x,y1,'r:')
axes.plot(x,y2,'b--')
plt.show()

# %%
t = np.arange(0,5,0.1)
y1 = np.sin(2*np.pi * t)
y2 = np.cos(2*np.pi * t)

figure = plt.figure(figsize=(8,5))
axes1 = figure.add_subplot(2,1,1)
#畫布列分割為2, 行分割為1, 呈現1圖塊 
axes2 = figure.add_subplot(2,1,2)
#畫布列分割為2, 行分割為1, 呈現2圖塊 
axes1.plot(t,y1,'r--')
axes2.plot(t,y2,'b--')
plt.show()
